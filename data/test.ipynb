# %%
import pandas as pd

df1 = pd.read_excel('Analyse factoren.xlsx', sheet_name='factor_prijzen')
df1.head()
# Out:
#        Grondstof   id          Subthema Data gevonden Bron  bron_id  \
# 0           Hout    5          Algemeen            Ja  NaN      3.0
# 1  Hout: massief  NaN   Beuken (regels)      maatwerk  NaN      NaN
# 2            NaN  NaN        Fins vuren      maatwerk  NaN      NaN
# 3            NaN  NaN             Eiken            Ja  NaN      NaN
# 4            NaN  NaN  Amerikaans noten      maatwerk  NaN      NaN
#
#        Periode Type bron (verversbaar) Detailniveau (exacte grondstof)  \
# 0  2020 tot nu                     NaN                             NaN
# 1     <vul in>                     NaN                             NaN
# 2     <vul in>                     NaN                             NaN
# 3     <vul in>                     NaN                             NaN
# 4     <vul in>                     NaN                             NaN
#
#    Betrouwbaarheid Opgenomen in Webapp  \
# 0              NaN                  Ja
# 1              NaN                 nee
# ...

# %%
df1['id'].unique()
# Out:
# array([5, nan, 9, 11, 10, 2, '?', 12, 14, 1, 15, 16, 3, 4, 17, 23, 24, 25,
#        26], dtype=object)
